# %%
import numpy as np
import glob
import cv2

categories = ['CNV', 'DME', 'DRUSEN', 'NORMAL']
nb_classes = len(categories)
image_w = 299
image_h = 299

caltech_dir1 = "D:/KIM"
x = []
y = []
print('Start test')

for idx, cat in enumerate(categories):  # 라벨링작업
    label = [0 for i in range(nb_classes)]
    label[idx] = 1
    image_dir = caltech_dir1 + "/"
    files = glob.glob(image_dir + cat + "/*")  # 경로에 대응되는 모든파일
    for i, f in enumerate(files):
        print(f)
        img = cv2.imread(f, cv2.IMREAD_COLOR)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        img = cv2.resize(img, (image_w, image_h))
        data = np.asarray(img) / 255
        data = data.reshape((image_w, image_h, 1))
        label = np.asarray(label)
        
        x.append(data)
        y.append(label)
        
X = np.array(x)
y = np.array(y)
np.save("train_mini.npy", X)
np.save("label_mini.npy", y)
print("ok test")
# Out:
# Start test
# D:/KIM/CNV\CNV-1016042-1 (2).jpeg
# D:/KIM/CNV\CNV-1016042-1.jpeg
# D:/KIM/CNV\CNV-1016042-10.jpeg
# D:/KIM/CNV\CNV-1016042-100.jpeg
# D:/KIM/CNV\CNV-1016042-101.jpeg
# D:/KIM/CNV\CNV-1016042-102.jpeg
# D:/KIM/CNV\CNV-1016042-103.jpeg
# D:/KIM/CNV\CNV-1016042-104.jpeg
# D:/KIM/CNV\CNV-1016042-105.jpeg
# D:/KIM/CNV\CNV-1016042-106.jpeg
# D:/KIM/CNV\CNV-1016042-107.jpeg
# D:/KIM/CNV\CNV-1016042-108.jpeg
# D:/KIM/CNV\CNV-1016042-109.jpeg
# D:/KIM/CNV\CNV-1016042-11.jpeg
# D:/KIM/CNV\CNV-1016042-110.jpeg
# D:/KIM/CNV\CNV-1016042-111.jpeg
# D:/KIM/CNV\CNV-1016042-112.jpeg
# D:/KIM/CNV\CNV-1016042-113.jpeg
# D:/KIM/CNV\CNV-1016042-114.jpeg
# D:/KIM/CNV\CNV-1016042-115.jpeg
# D:/KIM/CNV\CNV-1016042-116.jpeg
# D:/KIM/CNV\CNV-1016042-117.jpeg
# D:/KIM/CNV\CNV-1016042-118.jpeg
# D:/KIM/CNV\CNV-1016042-119.jpeg
# D:/KIM/CNV\CNV-1016042-12.jpeg
# D:/KIM/CNV\CNV-1016042-120.jpeg
# D:/KIM/CNV\CNV-1016042-121.jpeg
# D:/KIM/CNV\CNV-1016042-122.jpeg
# D:/KIM/CNV\CNV-1016042-123.jpeg
# ...

# %%
import matplotlib.pyplot as plt

img = Image.open("D:/KIM/CNV/CNV-13823-1.jpeg").convert('L')
img = img.resize((image_w, image_h))
data = np.array(img)
print(type(data))
print(data.shape)

plt.imshow(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-8094731c9641> in <module>
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 img = Image.open("D:/KIM/CNV/CNV-13823-1.jpeg").convert('L')
#       4 img = img.resize((image_w, image_h))
#       5 data = np.array(img)
#
# NameError: name 'Image' is not defined

# %%
import matplotlib.pyplot as plt
import cv2

img = cv2.imread("D:/KIM/CNV/CNV-13823-1.jpeg", cv2.IMREAD_COLOR)
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img = cv2.resize(img, (image_w, image_h))
data = np.asarray(img) / 255
data = data.reshape((image_w, image_h, 1))
print(data.shape)
print(type(data))

cv2.imshow('gray', data)
cv2.waitKey(0)
cv2.destoryAllWindows()
# Out:
# (299, 299, 1)
# <class 'numpy.ndarray'>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-93335accd9f5> in <module>
#      12 cv2.imshow('gray', data)
#      13 cv2.waitKey(0)
# ---> 14 cv2.destoryAllWindows()
#
# AttributeError: module 'cv2.cv2' has no attribute 'destoryAllWindows'

# %%
X_train = np.load('D:/OCT-Image/batch1/train_mini.npy')
X_label = np.load('D:/OCT-Image/batch1/label_mini.npy')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-32-de96cb198013> in <module>
# ----> 1 X_train = np.load('D:/OCT-Image/batch1/train_mini.npy')
#       2 X_label = np.load('D:/OCT-Image/batch1/label_mini.npy')
#
# ~\AppData\Roaming\Python\Python37\site-packages\numpy\lib\npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     451             else:
#     452                 return format.read_array(fid, allow_pickle=allow_pickle,
# --> 453                                          pickle_kwargs=pickle_kwargs)
#     454         else:
#     455             # Try a pickle
#
# ~\AppData\Roaming\Python\Python37\site-packages\numpy\lib\format.py in read_array(fp, allow_pickle, pickle_kwargs)
#     753         if isfileobj(fp):
#     754             # We can use the fast fromfile() function.
# ...
