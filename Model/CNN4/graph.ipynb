# %%
from math import pi
import matplotlib.pyplot as plt

# Set data
cat = ['CNV', 'DME', 'DRUSEN', 'NORMAL']
values = [340, 410, 77, 23]

N = len(cat)

x_as = [n / float(N) * 2 * pi for n in range(N)]

# Because our chart will be circular we need to append a copy of the first 
# value of each list at the end of each list with data
values += values[:1]
x_as += x_as[:1]


# Set color of axes
plt.rc('axes', linewidth=0.5, edgecolor="#888888")


# Create polar plot
ax = plt.subplot(111, polar=True)


# Set clockwise rotation. That is:
ax.set_theta_offset(pi / 2)
ax.set_theta_direction(-1)


# Set position of y-labels
ax.set_rlabel_position(0)


# Set color and linestyle of grid
ax.xaxis.grid(True, color="#888888", linestyle='solid', linewidth=0.5)
ax.yaxis.grid(True, color="#888888", linestyle='solid', linewidth=0.5)


# Set number of radial axes and remove labels
plt.xticks(x_as[:-1], [])

# Set yticks
plt.yticks([200, 400, 600, 800], ["200", "400", "600", "800"])


# Plot data
ax.plot(x_as, values, linewidth=0, linestyle='solid', zorder=3)

# Fill area
ax.fill(x_as, values, 'b', alpha=0.3)


# Set axes limits
plt.ylim(0, 800)


# Draw ytick labels to make sure they fit properly
for i in range(N):
    angle_rad = i / float(N) * 2 * pi

    if angle_rad == 0:
        ha, distance_ax = "center", 10
    elif 0 < angle_rad < pi:
        ha, distance_ax = "left", 1
    elif angle_rad == pi:
        ha, distance_ax = "center", 1
    else:
        ha, distance_ax = "right", 1

    ax.text(angle_rad, 850 + distance_ax, cat[i], size=10, horizontalalignment=ha, verticalalignment="center")


# Show polar plot
plt.show()

# %%
import matplotlib.pyplot as plt

categories = ['CNV', 'DME', 'DRUSEN', 'NORMAL']

fig = plt.figure()
fig, ax_lst = plt.subplots(4, 4, figsize=(15,15))

batch1_CNV= [340, 410, 77, 23]
ax_lst[0][0].pie(batch1_CNV, labels=categories, autopct='%0.1f%%')
batch1_DME = [12, 586, 29, 223]
ax_lst[1][0].pie(batch1_DME, labels=categories, autopct='%0.1f%%')
batch1_DRUSEN = [36, 198, 291, 325]
ax_lst[2][0].pie(batch1_DRUSEN, labels=categories, autopct='%0.1f%%')
batch1_NORMAL = [0, 72, 15, 763]
ax_lst[3][0].pie(batch1_NORMAL, labels=categories, autopct='%0.1f%%')


batch2_CNV= [540, 293, 53, 0]
ax_lst[0][1].pie(batch2_CNV, labels=categories, autopct='%0.1f%%')
batch2_DME = [35, 739, 21, 55]
ax_lst[1][1].pie(batch2_DME, labels=categories, autopct='%0.1f%%')
batch2_DRUSEN = [81, 384, 284, 101]
ax_lst[2][1].pie(batch2_DRUSEN, labels=categories, autopct='%0.1f%%')
batch2_NORMAL = [3, 242, 35, 570]
ax_lst[3][1].pie(batch2_NORMAL, labels=categories, autopct='%0.1f%%')

batch3_CNV= [478, 331, 40, 1]
ax_lst[0][2].pie(batch3_CNV, labels=categories, autopct='%0.1f%%')
batch3_DME = [23, 744, 21, 62]
ax_lst[1][2].pie(batch3_DME, labels=categories, autopct='%0.1f%%')
batch3_DRUSEN = [22, 435, 204, 189]
ax_lst[2][2].pie(batch3_DRUSEN, labels=categories, autopct='%0.1f%%')
batch3_NORMAL = [2, 208, 23, 617]
ax_lst[3][2].pie(batch3_NORMAL, labels=categories, autopct='%0.1f%%')

batch4_CNV= [480, 225, 126, 19]
ax_lst[0][3].pie(batch4_CNV, labels=categories, autopct='%0.1f%%')
batch4_DME = [55, 638, 54, 103]
ax_lst[1][3].pie(batch4_DME, labels=categories, autopct='%0.1f%%')
batch4_DRUSEN = [57, 226, 395, 172]
ax_lst[2][3].pie(batch4_DRUSEN, labels=categories, autopct='%0.1f%%')
batch4_NORMAL = [4, 66, 41, 739]
ax_lst[3][3].pie(batch4_NORMAL, labels=categories, autopct='%0.1f%%')

plt.rcParams["font.family"] = "Bahnschrift SemiBold"
plt.show()

# %%
import matplotlib.pyplot as plt

categories = ['CNV', 'DME', 'DRUSEN', 'NORMAL']

fig = plt.figure()
fig, ax_lst = plt.subplots(4, 4, figsize=(15,15))

batch1_CNV= [1705, 229, 2, 64]
ax_lst[0][0].pie(batch1_CNV, labels=categories, autopct='%0.1f%%')
batch1_DME = [180, 1389, 1, 430]
ax_lst[1][0].pie(batch1_DME, labels=categories, autopct='%0.1f%%')
batch1_DRUSEN = [631, 247, 134, 988]
ax_lst[2][0].pie(batch1_DRUSEN, labels=categories, autopct='%0.1f%%')
batch1_NORMAL = [7, 53, 0, 1940]
ax_lst[3][0].pie(batch1_NORMAL, labels=categories, autopct='%0.1f%%')


batch2_CNV= [1852, 96, 37, 15]
ax_lst[0][1].pie(batch2_CNV, labels=categories, autopct='%0.1f%%')
batch2_DME = [322, 1269, 18, 391]
ax_lst[1][1].pie(batch2_DME, labels=categories, autopct='%0.1f%%')
batch2_DRUSEN = [504, 129, 579, 788]
ax_lst[2][1].pie(batch2_DRUSEN, labels=categories, autopct='%0.1f%%')
batch2_NORMAL = [9, 39, 16, 1936]
ax_lst[3][1].pie(batch2_NORMAL, labels=categories, autopct='%0.1f%%')

batch3_CNV= [1215, 577, 56, 152]
ax_lst[0][2].pie(batch3_CNV, labels=categories, autopct='%0.1f%%')
batch3_DME = [89, 1493, 8, 410]
ax_lst[1][2].pie(batch3_DME, labels=categories, autopct='%0.1f%%')
batch3_DRUSEN = [425, 528, 232, 815]
ax_lst[2][2].pie(batch3_DRUSEN, labels=categories, autopct='%0.1f%%')
batch3_NORMAL = [5, 65, 3, 1927]
ax_lst[3][2].pie(batch3_NORMAL, labels=categories, autopct='%0.1f%%')

batch4_CNV= [1724, 188, 18, 70]
ax_lst[0][3].pie(batch4_CNV, labels=categories, autopct='%0.1f%%')
batch4_DME = [176, 1214, 2, 608]
ax_lst[1][3].pie(batch4_DME, labels=categories, autopct='%0.1f%%')
batch4_DRUSEN = [984, 227, 104, 685]
ax_lst[2][3].pie(batch4_DRUSEN, labels=categories, autopct='%0.1f%%')
batch4_NORMAL = [7, 49, 7, 1937]
ax_lst[3][3].pie(batch4_NORMAL, labels=categories, autopct='%0.1f%%')

plt.rcParams["font.family"] = "Franklin Gothic Medium"
plt.show()
